# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitasin123/codeclause_datascience/blob/main/project2_market_basket_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 2 :- Market Basket Analysis in Python using Apriori Algorithm

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
market_basket = pd.read_csv("market basket analysis.csv",encoding = 'latin1')
market_basket
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 431618    573665     21791   VINTAGE HEADS AND TAILS CARD GAME        8.0
# 431619    573665     22667                RECIPE BOX RETROSPOT        3.0
# 431620    573665     21121    SET/10 RED POLKADOT PARTY CANDLES       8.0
# 431621    573665     21888                            BINGO SET       4.0
# 431622    573665     22111                                   SC       NaN
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
market_basket.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
market_basket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431623 entries, 0 to 431622
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    431623 non-null  object
#  1   StockCode    431623 non-null  object
#  2   Description  430259 non-null  object
#  3   Quantity     431622 non-null  float64
#  4   InvoiceDate  431622 non-null  object
#  5   UnitPrice    431622 non-null  float64
#  6   CustomerID   323524 non-null  float64
#  7   Country      431622 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 26.3+ MB

# %% [markdown]
# Data cleansing

# %%
market_basket['Description'] = market_basket['Description'].str.strip()
market_basket.dropna(axis=0 ,subset = ['InvoiceNo'] , inplace=True)
market_basket['InvoiceNo' ] = market_basket['InvoiceNo'].astype('str')
market_basket = market_basket[~ market_basket['InvoiceNo'].str.contains('C')]

# %%
market_basket.shape
# Out:
# (423771, 8)

# %%
market_basket.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
market_basket.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  423770.000000  423770.000000  316029.000000
# mean       10.361765       3.886566   15279.551437
# std       125.975758      44.968958    1712.193932
# min     -9600.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13911.000000
# 50%         4.000000       2.080000   15144.000000
# 75%        12.000000       4.130000   16779.000000
# max     74215.000000   13541.330000   18287.000000

# %%
market_basket['Country'].value_counts()
# Out:
# United Kingdom          386187
# Germany                   7630
# France                    6539
# EIRE                      6491
# Spain                     2116
# Netherlands               2052
# Switzerland               1742
# Belgium                   1694
# Portugal                  1255
# Australia                 1142
# Norway                     816
# Channel Islands            670
# Finland                    598
# Italy                      574
# Cyprus                     514
# Unspecified                393
# Sweden                     374
# Austria                    321
# Israel                     295
# Japan                      289
# Denmark                    286
# Hong Kong                  283
# Poland                     259
# Singapore                  222
# Iceland                    171
# Canada                     151
# USA                        147
# Greece                     109
# Malta                      100
# United Arab Emirates        68
# ...

# %%
market_basket.shape
# Out:
# (423771, 8)

# %%
basket = (market_basket[market_basket['Country'] =="EIRE"]     
          .groupby(['InvoiceNo', 'Description'])['Quantity'] 
          .sum().unstack().reset_index().fillna(0) 
          .set_index('InvoiceNo'))

# %%
basket.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536540                          0.0                         0.0
# 536541                          0.0                         0.0
# 536803                          0.0                         0.0
# 536885                          0.0                         0.0
# 536890                          0.0                         0.0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536540                             0.0                        0.0
# 536541                             0.0                        0.0
# 536803                             0.0                        0.0
# 536885                             0.0                        0.0
# 536890                             0.0                        0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536540                                    0.0
# 536541                                    0.0
# ...

# %% [markdown]
# convert positive value as 1 and negative value as 0

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket.applymap(encode_units)

# %%
basket.shape
# Out:
# (236, 1854)

# %%
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536540                            0                           0
# 536541                            0                           0
# 536803                            0                           0
# 536885                            0                           0
# 536890                            0                           0
#
# Description  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# InvoiceNo
# 536540                               0                          0
# 536541                               0                          0
# 536803                               0                          0
# 536885                               0                          0
# 536890                               0                          0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536540                                      0
# 536541                                      0
# ...

# %% [markdown]
#  Frequent item sets that have a support of at least 7%

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)

# %% [markdown]
# Generate the rules with their corresponding support, confidence and lift.

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %%
rules.head()
# Out:
#                          antecedents                        consequents  \
# 0   (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
# 1  (GREEN REGENCY TEACUP AND SAUCER)   (PINK REGENCY TEACUP AND SAUCER)
# 2         (REGENCY CAKESTAND 3 TIER)  (GREEN REGENCY TEACUP AND SAUCER)
# 3  (GREEN REGENCY TEACUP AND SAUCER)         (REGENCY CAKESTAND 3 TIER)
# 4  (ROSES REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.088983            0.114407  0.080508    0.904762  7.908289
# 1            0.114407            0.088983  0.080508    0.703704  7.908289
# 2            0.258475            0.114407  0.080508    0.311475  2.722526
# 3            0.114407            0.258475  0.080508    0.703704  2.722526
# 4            0.161017            0.114407  0.101695    0.631579  5.520468
#
#    leverage  conviction
# 0  0.070328    9.298729
# 1  0.070328    3.074682
# ...

# %%
rules[(rules['lift'] >= 6) &
       (rules['confidence'] >= 0.7)]
# Out:
#                                           antecedents  \
# 0                    (PINK REGENCY TEACUP AND SAUCER)
# 1                   (GREEN REGENCY TEACUP AND SAUCER)
# 18                          (REGENCY TEA PLATE ROSES)
# 19                          (REGENCY TEA PLATE GREEN)
# 20  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 21  (ROSES REGENCY TEACUP AND SAUCER, GREEN REGENC...
# 24                   (PINK REGENCY TEACUP AND SAUCER)
# 26  (REGENCY CAKESTAND 3 TIER, ROSES REGENCY TEACU...
# 27  (REGENCY CAKESTAND 3 TIER, GREEN REGENCY TEACU...
# 31                  (GREEN REGENCY TEACUP AND SAUCER)
#
#                                           consequents  antecedent support  \
# 0                   (GREEN REGENCY TEACUP AND SAUCER)            0.088983
# 1                    (PINK REGENCY TEACUP AND SAUCER)            0.114407
# 18                          (REGENCY TEA PLATE GREEN)            0.093220
# ...

# %% [markdown]
# #Conclusion : -
#
# From the market basket analysis, it is found that customers who buy PINK REGENCY TEACUP AND SAUCER tend to buy GREEN REGENCY TEACUP AND SAUCER.
